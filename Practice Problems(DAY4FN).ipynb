# %% [markdown]
# # Matplotlib Exercise 1

# %% [markdown]
# **Q1. Days (x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line/curve plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.**<br>
#          Days=[1,2,3,4,5,6,7,8]<br>
#          Speed=[60,62,61,58,56,57,46,63]

# %%
import matplotlib.pyplot as plt
Days = [1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]
plt.plot(Days, Speed, color = 'blue') # For Create a Line Plot
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.title('Car Speed Measurement')
plt.show()

# %% [markdown]
# **Q2. Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.**

# %%
import matplotlib.pyplot as plt
Days = [1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]
plt.plot(Days, Speed, color = 'blue', marker = 'o', ms = 20, mec = 'red', mfc = 'green')
# ms for marker size, mfc for marker face color, mec for border color
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.title('Car Speed Measurement')
plt.show()

# %% [markdown]
# **Q3. Plot Axes Labels, Chart title, Legend in Car minimum, Maximum and average speed in 8 days as below.**<br>
# max_speed=[80,91,92,88,77,79,76,75]<br>
# min_speed=[42,43,40,42,33,36,34,35]<br>
# avg_speed=[46,58,57,56,40,42,41,36]<br>
# **Note: Utilize subplots()**

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5,6,7,8]
max_speed = [80,91,92,88,77,79,76,75]
min_speed = [42,43,40,42,33,36,34,35]
avg_speed = [46,58,57,56,40,42,41,36]
#plt.figure(figsize=(8,6))
fig, axes = plt.subplots(3,1,figsize=(8,6))
axes[0].plot(Days, max_speed, color = 'red', marker = '*', ms = 10, mec = 'red', mfc='red')
axes[0].set_xlabel('Days')
axes[0].set_ylabel('Maximum Speed')
axes[0].set_title('Car Speed Measurement')
axes[0].legend()
axes[1].plot(Days, min_speed, color = 'green', marker = 'o', ms = 10, mec = 'black')
axes[1].set_xlabel('Days')
axes[1].set_ylabel('Minimum Speed')
axes[1].set_title('Car Speed Measurement')
axes[1].legend()
axes[2].plot(Days, avg_speed, color = 'yellow', marker = '^', ms = 10, mec = 'red')
axes[2].set_xlabel('Days')
axes[2].set_ylabel('Average Speed')
axes[2].set_title('Car Speed Measurement')
axes[2].legend()
axes[2].grid()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# **Q4. Plotting a basic sine graph by adding more features. Also adding Multiple plots by Superimposition like cosine wave.**

# %%
import numpy as np
x = np.arange(0,4*np.pi,0.1)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, color = 'green', marker='o')
plt.plot(x,z, color = 'blue', marker = '*')
plt.xlabel('Sin and Cos Value From 0 to 4pi')
plt.ylabel('Sin(x) and Cos(x)')
plt.title('Sin And Cosine Wave')
plt.legend(['sin(X)','Cos(x)'])
plt.show()

# %% [markdown]
# **Q5. Consider that a survey has to be done on how much distance the following vehicles have covered in a span of five days. The data collected can be plotted in different plotting methods.**<br>
#     (i) Line Plotting on same figure with different labels and colors.
# <img src='Q5.jpg'>

# %%
#days=[1,2,3,4,5]
days=['DAY 1','DAY 2','DAY 3','DAY 4','DAY 5']
enfield=[50,40,70,80,20]
honda=[80,20,20,50,60]
yamaha=[70,20,60,40,60]
ktm=[80,20,20,50,60]

plt.plot(days,enfield,'g',label='Enfield',)

# %% [markdown]
# **Q6. In this example, use Pandas and Matplotlib to visualize 'Company Sales Data'.**<br>
#     **(i) Read Total profit of all months and show it using a line plot.**<br>
#         Total profit data provided for each month. Generated line plot must include the following properties: –<br>
#         X label name = Month Number<br>
#         Y label name = Total profit<br>
#     **(ii) Get total profit of all months and show line plot with the following Style properties**<br>
#     Line Style dotted and Line-color should be red.<br>
#     Show legend at the lower right location.<br>
#     X label name = Month Number.<br>
#     Y label name = Sold units number.<br>
#     Add a circle marker.<br>
#     Line marker color as read.<br>
#     Line width should be 3.<br>
#     **(iii) Read all product sales data and show it  using a multiline plot.**<br>

# %%
# (i)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Abhi\\Desktop\\SRET\\Advance Python Programming\\Module")
profitList = df['total_profit'].tolist()
monthList = df['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19676/78672923.py in <module>
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 df = pd.read_csv("C:\\Users\\Abhi\\Desktop\\SRET\\Advance Python Programming\\Module")
#       5 profitList = df['total_profit'].tolist()
#       6 monthList = df['month_number'].tolist()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# (ii)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Abhi\\Desktop\\SRET\\Advance Python Programming\\Module
profitList = df ['total_profit'].tolist()
monthList = df ['month_number'].tolist()
plt.plot(monthList,profitList,label='Profit data of last year',color='r',marker='o',
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.legend(loc='lower right')
plt.title('Company Sales data of last year')
plt.xticks(monthList)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %%
# (iii)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Abhi\\Desktop\\SRET\\Advance Python Programming\\Module
monthList = df ['month_number'].tolist()
faceCremSalesData = df ['facecream'].tolist()
faceWashSalesData = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData = df ['bathingsoap'].tolist()
shampooSalesData = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()
plt.plot(monthList, faceCremSalesData, label = 'Face cream Sales Data', marker='o')
plt.plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', marker='o')
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o')
plt.plot(monthList, bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o')
plt.plot(monthList, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', l)
plt.plot(monthList, moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %% [markdown]
# # Great Job!
