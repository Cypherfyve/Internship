# %% [markdown]
# # Matplotlib Exercise 2

# %% [markdown]
# **Q1. Plot Simple bar chart showing popularity of Programming Languages.**<br>
#     Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']<br>
#     Popularity = [56, 39, 34, 34, 29]<br>
#     Security = [44 ,36 ,55, 50, 42]<br>
#
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
import matplotlib.pyplot as plt
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]
plt.subplot(2,1,1)
plt.bar(Languages, Popularity, width=0.5, color = 'orange', align='center')
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.legend(['Popularity'])
plt.show()
plt.subplot(2,1,2)
plt.barh(Languages,Security,color='red',align='center')
plt.xlabel('Languages')
plt.ylabel('Security')
plt.legend(['Security'])

# %% [markdown]
# **Q2. Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.**<br><br>
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]<br><br>
#
# Histogram showing Below Average, Average and Execellent distribution<br>
#
# 40-60: Below Average<br>
#
# 60-80: Average<br>
#
# 80-100: Excellent<br>
# <br>
#
# Note: use np.logical_and()

# %%
import numpy as np
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
below_avg = Marks[np.logical_and(Marks >= 40, Marks < 60)]
avg_marks = Marks[np.logical_and(Marks >= 60, Marks < 80)]
exe_marks = Marks[np.logical_and(Marks >= 80, Marks <= 100)]
plt.hist(Marks)
plt.show()
print('Below Average Students Are : ',below_avg.size)
print('Average Students Are : ',avg_marks.size)
print('Execelent Students Are : ',exe_marks.size)
# Out:
# Below Average Students Are :  5
# Average Students Are :  8
# Execelent Students Are :  4

# %% [markdown]
# **Q3. Load the Titanic data set file from the location, then perform the following operations-**<br>
#
#  (i) Create a pie chart presenting the male/female proportion.<br>
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender.

# %%
# (i)
import pandas as pd
df = pd.read_csv('titanic_original.csv')
df.head()
df['sex']
x = df.sex.value_counts()
plt.pie(x, autopct='%.0f%%')
plt.legend(['Male','Female'])
plt.title('Male And Female Proportion')
plt.show()

# %%
# (ii)
male = df[df['sex']=='male']
male.sex.value_counts()
plt.scatter(male.fare, male.age, label = 'Male', marker = '*')
female = df[df['sex']=='female']
female.sex.value_counts()
plt.scatter(female.fare, female.age, label = 'Female', marker = '^')
plt.legend()
plt.xlabel('Fare')
plt.ylabel('Age')
plt.grid()
plt.show()

# %% [markdown]
# **Q4. In this example, use Pandas and Matplotlib to visualize 'Company Sales Data'.**<br>
#     **(i) Read toothpaste sales data of each month and show it using a scatter plot.**<br>
#         Add a grid in the plot. gridline style should '--'.<br>
#     **(ii) Read face cream and facewash product sales data and show it using the bar chart**<br>
#         The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.<br>
#     **(iii) Calculate total sale data for last year for each product and show it using a Pie chart.**<br>
#     **(iv) Read the total profit of each month and calculate it using the boxplot as well as display median, minimum, maximum of total profit.**

# %%
# (i)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("company_sales_data.csv")
monthList = df['month_number'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
plt.scatter(monthList, toothPasteSalesData, label = 'Tooth paste Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.legend(loc='upper left')
plt.title(' Tooth paste Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %%
# (ii)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("company_sales_data.csv")
monthList = df ['month_number'].tolist()
faceCremSalesData = df ['facecream'].tolist()
faceWashSalesData = df ['facewash'].tolist()

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream'
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash'
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')
plt.xticks(monthList)
plt.title('Facewash and facecream sales data')
plt.show()
# Out:
#   File "C:\Users\saivi\AppData\Local\Temp/ipykernel_36304/3871026929.py", line 9
#     plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream'
#     ^
# IndentationError: unexpected indent

# %%
# (iii)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("company_sales_data.csv")
monthList = df ['month_number'].tolist()
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moistur
totalSalesData = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste']
df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
plt.pie(totalSalesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc=0)
plt.title('Sales data')
plt.show()

# %%
# (iv)
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("company_sales_data.csv")
profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
bp = plt.boxplot(profitList, vert=True,patch_artist=True,notch=True, labels = ['total']
plt.show()
median = [item.get_ydata()[0] for item in bp['medians']]
minimum, maximum = [item.get_ydata()[0] for item in bp['caps']]
print(f'Median: {median}\n' f'Minimum: {minimum}\n' f'Maximum: {maximum}')

# %% [markdown]
# **Q5. Consider that a survey has to be done on how much distance the following vehicles have covered in a span of five days. The data collected can be plotted in different plotting methods.**<br>
#     (i) Scatter plot of bike distance covers.
# <img src='Q5.jpg'>

# %%
days = ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5']
Y1 = [50, 40, 70, 80, 20]
Y2=[80, 20, 20, 50, 60]
Y3=[70, 20, 60, 40, 60]
Y4=[80, 20, 20, 50, 60]
plt.scatter(days,Y1, label='Enfield',color='r')
plt.scatter(days,Y2,label='Honda',color='b')
plt.scatter(days,Y3,label='Yahama',color='y')
plt.scatter(days,Y4,label='KTM',color='k')
plt.xlabel('Days')
plt.ylabel('Distance in kms')
plt.title('Bike details in Scatter Plot')
plt.legend()

# %% [markdown]
# # Great Job!
